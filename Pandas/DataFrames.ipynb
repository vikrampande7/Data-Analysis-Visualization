# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
import webbrowser
website = 'http://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_df = pd.read_clipboard()

# %%
nfl_df
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,401  782   581    38  0.572
# 1     2        Dallas Cowboys    947  538   403     6  0.571
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,435  783   610    42  0.560
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division
# 0              1921  NFC North
# 1              1960   NFC East
# 2              1960   AFC East
# 3              1920  NFC North
# 4              1996  AFC North

# %%
nfl_df.columns
# Out:
# Index(['Rank', 'Team', 'GP', 'Won', 'Lost', 'Tied', 'Pct.', 'First NFL season',
#        'Division'],
#       dtype='object')

# %%
nfl_df.Rank
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Rank, dtype: int64

# %%
nfl_df.Team
# Out:
# 0       Green Bay Packers
# 1          Dallas Cowboys
# 2    New England Patriots
# 3           Chicago Bears
# 4        Baltimore Ravens
# Name: Team, dtype: object

# %%
nfl_df['First NFL season']
# Out:
# 0    1921
# 1    1960
# 2    1960
# 3    1920
# 4    1996
# Name: First NFL season, dtype: int64

# %%
DataFrame(nfl_df, columns = ['Rank','Team','GP','Won','Lost','Tied'])
# Out:
#    Rank                  Team     GP  Won  Lost  Tied
# 0     1     Green Bay Packers  1,401  782   581    38
# 1     2        Dallas Cowboys    947  538   403     6
# 2     3  New England Patriots    949  529   411     9
# 3     4         Chicago Bears  1,435  783   610    42
# 4     5      Baltimore Ravens    417  233   183     1

# %%
DataFrame(nfl_df, columns = ['Rank','Team','GP','Won','Lost','Tied','Yo'])
# Out:
#    Rank                  Team     GP  Won  Lost  Tied  Yo
# 0     1     Green Bay Packers  1,401  782   581    38 NaN
# 1     2        Dallas Cowboys    947  538   403     6 NaN
# 2     3  New England Patriots    949  529   411     9 NaN
# 3     4         Chicago Bears  1,435  783   610    42 NaN
# 4     5      Baltimore Ravens    417  233   183     1 NaN

# %%
nfl_df
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,401  782   581    38  0.572
# 1     2        Dallas Cowboys    947  538   403     6  0.571
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,435  783   610    42  0.560
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division
# 0              1921  NFC North
# 1              1960   NFC East
# 2              1960   AFC East
# 3              1920  NFC North
# 4              1996  AFC North

# %%
nfl_df.head()
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,401  782   581    38  0.572
# 1     2        Dallas Cowboys    947  538   403     6  0.571
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,435  783   610    42  0.560
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division
# 0              1921  NFC North
# 1              1960   NFC East
# 2              1960   AFC East
# 3              1920  NFC North
# 4              1996  AFC North

# %%
nfl_df.tail(3)
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,435  783   610    42  0.560
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division
# 2              1960   AFC East
# 3              1920  NFC North
# 4              1996  AFC North

# %%
nfl_df.iloc[2]
# Out:
# Rank                                   3
# Team                New England Patriots
# GP                                   949
# Won                                  529
# Lost                                 411
# Tied                                   9
# Pct.                               0.562
# First NFL season                    1960
# Division                        AFC East
# Name: 2, dtype: object

# %%
nfl_df['Stadium']="Levi's Stadium"

# %%
nfl_df
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,401  782   581    38  0.572
# 1     2        Dallas Cowboys    947  538   403     6  0.571
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,435  783   610    42  0.560
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division         Stadium
# 0              1921  NFC North  Levi's Stadium
# 1              1960   NFC East  Levi's Stadium
# 2              1960   AFC East  Levi's Stadium
# 3              1920  NFC North  Levi's Stadium
# 4              1996  AFC North  Levi's Stadium

# %%
nfl_df['Stadium']=np.arange(5)

# %%
nfl_df
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,401  782   581    38  0.572
# 1     2        Dallas Cowboys    947  538   403     6  0.571
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,435  783   610    42  0.560
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division  Stadium
# 0              1921  NFC North        0
# 1              1960   NFC East        1
# 2              1960   AFC East        2
# 3              1920  NFC North        3
# 4              1996  AFC North        4

# %%
stadiums = Series(["Levi's Stadium","AT&T Stadium"],index=[4,0])

# %%
nfl_df['Stadium'] = stadiums

# %%
nfl_df
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,401  782   581    38  0.572
# 1     2        Dallas Cowboys    947  538   403     6  0.571
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,435  783   610    42  0.560
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division         Stadium
# 0              1921  NFC North    AT&T Stadium
# 1              1960   NFC East             NaN
# 2              1960   AFC East             NaN
# 3              1920  NFC North             NaN
# 4              1996  AFC North  Levi's Stadium

# %%
del nfl_df['Stadium']

# %%
nfl_df
# Out:
#    Rank                  Team     GP  Won  Lost  Tied   Pct.  \
# 0     1     Green Bay Packers  1,401  782   581    38  0.572
# 1     2        Dallas Cowboys    947  538   403     6  0.571
# 2     3  New England Patriots    949  529   411     9  0.562
# 3     4         Chicago Bears  1,435  783   610    42  0.560
# 4     5      Baltimore Ravens    417  233   183     1  0.560
#
#    First NFL season   Division
# 0              1921  NFC North
# 1              1960   NFC East
# 2              1960   AFC East
# 3              1920  NFC North
# 4              1996  AFC North

# %%
data = {'City':['SF','LA','NYC'],
        'Population':[837000,3880000,8400000]}
city_frame = DataFrame(data)

city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC     8400000
